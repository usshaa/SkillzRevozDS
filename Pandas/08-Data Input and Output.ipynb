# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('Salaries.csv')
df.columns
df2 = df[['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay']]
df2
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  OvertimePay
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                                ...        ...          ...
# 148649                                       Custodian       0.00         0.00
# 148650                                    Not provided        NaN          NaN
# 148651                                    Not provided        NaN          NaN
# 148652                                    Not provided        NaN          NaN
# 148653                      Counselor, Log Cabin Ranch       0.00         0.00
#
# [148654 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
pd.set_option('display.max_rows',80)

# %%
df.head(80)
# Out:
#     Id          EmployeeName  \
# 0    1        NATHANIEL FORD
# 1    2          GARY JIMENEZ
# 2    3        ALBERT PARDINI
# 3    4     CHRISTOPHER CHONG
# 4    5       PATRICK GARDNER
# 5    6        DAVID SULLIVAN
# 6    7             ALSON LEE
# 7    8         DAVID KUSHNER
# 8    9        MICHAEL MORRIS
# 9   10    JOANNE HAYES-WHITE
# 10  11         ARTHUR KENNEY
# 11  12      PATRICIA JACKSON
# 12  13     EDWARD HARRINGTON
# 13  14           JOHN MARTIN
# 14  15        DAVID FRANKLIN
# 15  16       RICHARD CORRIEA
# 16  17              AMY HART
# 17  18        SEBASTIAN WONG
# 18  19            MARTY ROSS
# 19  20         ELLEN MOFFATT
# 20  21            VENUS AZAR
# 21  22          JUDY MELINEK
# 22  23         GEORGE GARCIA
# 23  24         VICTOR WYRSCH
# 24  25       JOSEPH DRISCOLL
# 25  26          GREGORY SUHR
# 26  27           JOHN HANLEY
# 27  28        RAYMOND GUZMAN
# 28  29        DENISE SCHMITT
# 29  30         MONICA FIELDS
# 30  31       HARLAN KELLY-JR
# 31  32           DAVID SHINN
# 32  33           GARY AMELIO
# 33  34            JOHN TURSI
# 34  35             JOSE VELO
# 35  36            KHOA TRINH
# 36  37          SUSAN CURRIN
# 37  38           JAMES BOSCH
# 38  39            JONES WONG
# 39  40          BRENDAN WARD
# 40  41      MICHAEL THOMPSON
# 41  42         THOMAS ABBOTT
# 42  43       THOMAS SIRAGUSA
# 43  44      MICHAEL THOMPSON
# 44  45  SHARON MCCOLE WICHER
# 45  46             EDWIN LEE
# 46  47      BRYAN RUBENSTEIN
# 47  48          TRENT RHORER
# 48  49          JAMES DUDLEY
# 49  50               KEN YEE
# 50  51       KIRK RICHARDSON
# 51  52        BARBARA GARCIA
# 52  53      MICHAEL ROLOVICH
# 53  54         DARRYL HUNTER
# 54  55          RAY CRAWFORD
# 55  56         KEVIN CASHMAN
# 56  57   BENJAMIN ROSENFIELD
# 57  58          MARK KEARNEY
# 58  59          DOUGLAS RIBA
# 59  60        AI-KYUNG CHUNG
# 60  61         KENNETH SMITH
# 61  62            ANNA BROWN
# 62  63     JAMES FAZACKERLEY
# 63  64         CHARLES CRANE
# 64  65           GREGORY MAR
# 65  66         RICHARD PARRY
# 66  67         ROBERT POSTEL
# 67  68         EDWARD ROLAND
# 68  69        THOMAS SHAWYER
# 69  70             WING CHAN
# 70  71         GEORGE GASCON
# 71  72    RICHARD BUSALACCHI
# 72  73        LAWRENCE FREED
# 73  74         MONIQUE MOYER
# 74  75        ANTONIO FLORES
# 75  76           MARK GAMBLE
# 76  77           KEVIN BURKE
# 77  78            BERT REYES
# 78  79        MICHAEL DELANE
# 79  80      EDUARDO GONZALEZ
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# 5                           ASSISTANT DEPUTY CHIEF II  118602.00      8601.00
# 6                  BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01     89062.90
# 7                      DEPUTY DIRECTOR OF INVESTMENTS  256576.96         0.00
# 8                  BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64     86362.68
# 9              CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00         0.00
# 10   ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39     71344.88
# 11                    CAPTAIN III (POLICE DEPARTMENT)   99722.00     87082.62
# 12                        EXECUTIVE CONTRACT EMPLOYEE  294580.02         0.00
# 13                                  DEPARTMENT HEAD V  271329.03         0.00
# 14                 BATTALION CHIEF, (FIRE DEPARTMENT)  174872.64     74050.30
# 15                 COMMANDER III, (POLICE DEPARTMENT)  198778.01     73478.20
# 16                                  DEPARTMENT HEAD V  268604.57         0.00
# 17              CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87    119397.26
# 18                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63     69626.12
# 19                         ASSISTANT MEDICAL EXAMINER  257510.59       880.16
# 20                         ASSISTANT MEDICAL EXAMINER  257510.48         0.00
# 21                         ASSISTANT MEDICAL EXAMINER  257510.44       377.21
# 22                          CAPTAIN, FIRE SUPPRESSION  140546.88     93200.58
# 23                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63     77896.14
# 24                          CAPTAIN, FIRE SUPPRESSION  140546.86     97868.77
# 25                                    CHIEF OF POLICE  256470.41         0.00
# 26                          CAPTAIN, FIRE SUPPRESSION   92080.80     40008.00
# 27                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.59     80706.88
# 28               DEPUTY CHIEF III (POLICE DEPARTMENT)  261717.60         0.00
# 29       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  246225.60         0.00
# 30                        EXECUTIVE CONTRACT EMPLOYEE  234325.02         0.00
# 31               DEPUTY CHIEF III (POLICE DEPARTMENT)  254027.63         0.00
# 32                                  DEPARTMENT HEAD V  248895.70         0.00
# 33                 INSPECTOR III, (POLICE DEPARTMENT)  104861.39     50227.61
# 34                 BATTALION CHIEF, (FIRE DEPARTMENT)  177781.25     59924.97
# 35                  ELECTRONIC MAINTENANCE TECHNICIAN  101953.20    139102.95
# 36                 ADMINISTRATOR, SFGH MEDICAL CENTER  245124.44         0.00
# 37                 INSPECTOR III, (POLICE DEPARTMENT)  110661.20     31162.04
# 38                 LIEUTENANT III (POLICE DEPARTMENT)  132202.26     52648.92
# 39                 BATTALION CHIEF, (FIRE DEPARTMENT)  147158.85     64985.85
# 40                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.66     60847.56
# 41                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.63     59760.90
# 42       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  218930.76      4078.00
# 43                                        FIREFIGHTER  123013.02    111729.65
# 44                     NURSING SUPERVISOR PSYCHIATRIC  196081.86         0.00
# 45                                              MAYOR  249375.02         0.00
# 46                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.64     66199.23
# 47                                  DEPARTMENT HEAD V  248895.77         0.00
# 48               DEPUTY CHIEF III (POLICE DEPARTMENT)  233867.60         0.00
# 49                        LIEUTENANT, FIRE DEPARTMENT  137729.92     89856.01
# 50                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.59     58084.86
# 51                                  DEPARTMENT HEAD V  246305.62         0.00
# 52                          CAPTAIN, FIRE SUPPRESSION  140546.87     77937.25
# 53                          CAPTAIN, FIRE SUPPRESSION  140546.88     73207.61
# 54              CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.89     82428.76
# 55               DEPUTY CHIEF III (POLICE DEPARTMENT)  226206.80         0.00
# 56                                  DEPARTMENT HEAD V  240731.93         0.00
# 57                          ASSISTANT DEPUTY CHIEF II  217410.80         0.00
# 58                        INCIDENT SUPPORT SPECIALIST  115381.02    105028.94
# 59                                        ANESTHETIST  214745.44      9161.31
# 60                        LIEUTENANT, FIRE DEPARTMENT  123105.00     99584.94
# 61                    CAPTAIN III (POLICE DEPARTMENT)  102571.24      7437.00
# 62              CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.86     80411.90
# 63                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.62     54342.28
# 64                 LIEUTENANT III (POLICE DEPARTMENT)  148970.43     66977.63
# 65                    CAPTAIN III (POLICE DEPARTMENT)  185369.69     37873.61
# 66   ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  177914.76     36644.57
# 67                          CAPTAIN, FIRE SUPPRESSION  139167.39     66596.28
# 68               DEPUTY CHIEF III (POLICE DEPARTMENT)  122974.00         0.00
# 69                        INCIDENT SUPPORT SPECIALIST  115455.44    104632.95
# 70                                  DISTRICT ATTORNEY  220983.12         0.00
# 71                 BATTALION CHIEF, (FIRE DEPARTMENT)   92782.61      5477.62
# 72  ELECTRICAL TRANSIT MECHANIC, ASSISTANT SUPERVISOR   95770.80    118949.93
# 73                                      PORT DIRECTOR  233357.28         0.00
# 74                 INSPECTOR III, (POLICE DEPARTMENT)  130457.88     51864.26
# 75                 INSPECTOR III, (POLICE DEPARTMENT)   85578.61     42878.01
# 76                 BATTALION CHIEF, (FIRE DEPARTMENT)  174872.64     16876.74
# 77  LIEUTENANT, BUREAU OF FIRE PREVENTION AND PUBL...   73754.05     18679.06
# 78                          CAPTAIN, FIRE SUPPRESSION  140546.88     62283.70
# 79                 BATTALION CHIEF, (FIRE DEPARTMENT)  168692.62     35096.74
#
#      OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 0   400184.25       NaN  567595.43         567595.43  2011    NaN
# 1   137811.38       NaN  538909.28         538909.28  2011    NaN
# 2    16452.60       NaN  335279.91         335279.91  2011    NaN
# 3   198306.90       NaN  332343.61         332343.61  2011    NaN
# 4   182234.59       NaN  326373.19         326373.19  2011    NaN
# 5   189082.74       NaN  316285.74         316285.74  2011    NaN
# 6   134426.14       NaN  315981.05         315981.05  2011    NaN
# 7    51322.50       NaN  307899.46         307899.46  2011    NaN
# 8    40132.23       NaN  303427.55         303427.55  2011    NaN
# 9    17115.73       NaN  302377.73         302377.73  2011    NaN
# 10   33149.90       NaN  299494.17         299494.17  2011    NaN
# 11  110804.30       NaN  297608.92         297608.92  2011    NaN
# 12       0.00       NaN  294580.02         294580.02  2011    NaN
# 13   21342.59       NaN  292671.62         292671.62  2011    NaN
# 14   37424.11       NaN  286347.05         286347.05  2011    NaN
# 15   13957.65       NaN  286213.86         286213.86  2011    NaN
# 16   16115.86       NaN  284720.43         284720.43  2011    NaN
# 17   18625.08       NaN  278569.21         278569.21  2011    NaN
# 18   38115.47       NaN  276434.22         276434.22  2011    NaN
# 19   16159.50       NaN  274550.25         274550.25  2011    NaN
# 20   16679.79       NaN  274190.27         274190.27  2011    NaN
# 21   15883.56       NaN  273771.21         273771.21  2011    NaN
# 22   39955.25       NaN  273702.71         273702.71  2011    NaN
# 23   24083.86       NaN  270672.63         270672.63  2011    NaN
# 24   31909.28       NaN  270324.91         270324.91  2011    NaN
# 25   11522.18       NaN  267992.59         267992.59  2011    NaN
# 26  133695.76       NaN  265784.56         265784.56  2011    NaN
# 27   16063.99       NaN  265463.46         265463.46  2011    NaN
# 28    2357.00       NaN  264074.60         264074.60  2011    NaN
# 29   15140.54       NaN  261366.14         261366.14  2011    NaN
# 30   25972.64       NaN  260297.66         260297.66  2011    NaN
# 31    5899.48       NaN  259927.11         259927.11  2011    NaN
# 32   10789.18       NaN  259684.88         259684.88  2011    NaN
# 33  103499.39       NaN  258588.39         258588.39  2011    NaN
# 34   20658.00       NaN  258364.22         258364.22  2011    NaN
# 35   16483.94       NaN  257540.09         257540.09  2011    NaN
# 36   12000.00       NaN  257124.44         257124.44  2011    NaN
# 37  111446.20       NaN  253269.44         253269.44  2011    NaN
# 38   67083.83       NaN  251935.01         251935.01  2011    NaN
# 39   39540.46       NaN  251685.16         251685.16  2011    NaN
# 40   21055.17       NaN  250595.39         250595.39  2011    NaN
# 41   21954.96       NaN  250408.49         250408.49  2011    NaN
# 42   27330.59       NaN  250339.35         250339.35  2011    NaN
# 43   15575.26       NaN  250317.93         250317.93  2011    NaN
# 44   54040.18       NaN  250122.04         250122.04  2011    NaN
# 45       0.00       NaN  249375.02         249375.02  2011    NaN
# 46   14401.43       NaN  249293.30         249293.30  2011    NaN
# 47       0.00       NaN  248895.77         248895.77  2011    NaN
# 48   14851.04       NaN  248718.64         248718.64  2011    NaN
# 49   20848.46       NaN  248434.39         248434.39  2011    NaN
# 50   20477.16       NaN  247254.61         247254.61  2011    NaN
# 51       0.00       NaN  246305.62         246305.62  2011    NaN
# 52   26203.69       NaN  244687.81         244687.81  2011    NaN
# 53   28988.36       NaN  242742.85         242742.85  2011    NaN
# 54   18310.77       NaN  241286.42         241286.42  2011    NaN
# 55   15004.37       NaN  241211.17         241211.17  2011    NaN
# 56     114.37       NaN  240846.30         240846.30  2011    NaN
# 57   22608.30       NaN  240019.10         240019.10  2011    NaN
# 58   19016.40       NaN  239426.36         239426.36  2011    NaN
# 59   14972.45       NaN  238879.20         238879.20  2011    NaN
# 60   16113.62       NaN  238803.56         238803.56  2011    NaN
# 61  128543.64       NaN  238551.88         238551.88  2011    NaN
# 62   17542.29       NaN  238501.05         238501.05  2011    NaN
# 63   15444.38       NaN  238479.28         238479.28  2011    NaN
# 64   21889.67       NaN  237837.73         237837.73  2011    NaN
# 65   14465.53       NaN  237708.83         237708.83  2011    NaN
# 66   22785.08       NaN  237344.41         237344.41  2011    NaN
# 67   31070.15       NaN  236833.82         236833.82  2011    NaN
# 68  113226.92       NaN  236200.92         236200.92  2011    NaN
# 69   14776.81       NaN  234865.20         234865.20  2011    NaN
# 70   13864.99       NaN  234848.11         234848.11  2011    NaN
# 71  135684.25       NaN  233944.48         233944.48  2011    NaN
# 72   18743.90       NaN  233464.63         233464.63  2011    NaN
# 73       0.00       NaN  233357.28         233357.28  2011    NaN
# 74   50380.44       NaN  232702.58         232702.58  2011    NaN
# 75  104030.10       NaN  232486.72         232486.72  2011    NaN
# 76   40258.39       NaN  232007.77         232007.77  2011    NaN
# 77  139279.69       NaN  231712.80         231712.80  2011    NaN
# 78   28821.55       NaN  231652.13         231652.13  2011    NaN
# 79   27802.89       NaN  231592.25         231592.25  2011    NaN
#
#            Agency  Status
# 0   San Francisco     NaN
# 1   San Francisco     NaN
# 2   San Francisco     NaN
# 3   San Francisco     NaN
# 4   San Francisco     NaN
# 5   San Francisco     NaN
# 6   San Francisco     NaN
# 7   San Francisco     NaN
# 8   San Francisco     NaN
# 9   San Francisco     NaN
# 10  San Francisco     NaN
# 11  San Francisco     NaN
# 12  San Francisco     NaN
# 13  San Francisco     NaN
# 14  San Francisco     NaN
# 15  San Francisco     NaN
# 16  San Francisco     NaN
# 17  San Francisco     NaN
# 18  San Francisco     NaN
# 19  San Francisco     NaN
# 20  San Francisco     NaN
# 21  San Francisco     NaN
# 22  San Francisco     NaN
# 23  San Francisco     NaN
# 24  San Francisco     NaN
# 25  San Francisco     NaN
# 26  San Francisco     NaN
# 27  San Francisco     NaN
# 28  San Francisco     NaN
# 29  San Francisco     NaN
# 30  San Francisco     NaN
# 31  San Francisco     NaN
# 32  San Francisco     NaN
# 33  San Francisco     NaN
# 34  San Francisco     NaN
# 35  San Francisco     NaN
# 36  San Francisco     NaN
# 37  San Francisco     NaN
# 38  San Francisco     NaN
# 39  San Francisco     NaN
# 40  San Francisco     NaN
# 41  San Francisco     NaN
# 42  San Francisco     NaN
# 43  San Francisco     NaN
# 44  San Francisco     NaN
# 45  San Francisco     NaN
# 46  San Francisco     NaN
# 47  San Francisco     NaN
# 48  San Francisco     NaN
# 49  San Francisco     NaN
# 50  San Francisco     NaN
# 51  San Francisco     NaN
# 52  San Francisco     NaN
# 53  San Francisco     NaN
# 54  San Francisco     NaN
# 55  San Francisco     NaN
# 56  San Francisco     NaN
# 57  San Francisco     NaN
# 58  San Francisco     NaN
# 59  San Francisco     NaN
# 60  San Francisco     NaN
# 61  San Francisco     NaN
# 62  San Francisco     NaN
# 63  San Francisco     NaN
# 64  San Francisco     NaN
# 65  San Francisco     NaN
# 66  San Francisco     NaN
# 67  San Francisco     NaN
# 68  San Francisco     NaN
# 69  San Francisco     NaN
# 70  San Francisco     NaN
# 71  San Francisco     NaN
# 72  San Francisco     NaN
# 73  San Francisco     NaN
# 74  San Francisco     NaN
# 75  San Francisco     NaN
# 76  San Francisco     NaN
# 77  San Francisco     NaN
# 78  San Francisco     NaN
# 79  San Francisco     NaN

# %% [markdown]
# ### CSV Output

# %%
df2.to_csv('murugan.csv',index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/lib/python3.7/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.7/site-packages (from openpyxl) (1.1.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import openpyxl
ex = pd.read_excel('Project-01_Excel_Data.xlsx',sheet_name='Data')
ex
# Out:
#     Name of Child Date of Birth            Place of Birth  MyKid Number  \
# 0        Victoria    2018-04-03  Selangor State, Malaysia        183926
# 1             Ava    2019-02-05     Johor State, Malaysia        826919
# 2           David    2023-05-07    Penang State, Malaysia        940662
# 3           Grace    2005-05-18     Johor State, Malaysia        353972
# 4          Daniel    2014-05-20     Johor State, Malaysia        693488
# ..            ...           ...                       ...           ...
# 94          Dylan    2011-04-23     Johor State, Malaysia        986256
# 95            Ava    2018-08-16     Johor State, Malaysia        998803
# 96        William    2010-02-25     Johor State, Malaysia        910972
# 97         Evelyn    2010-03-11    Penang State, Malaysia        940334
# 98        William    2006-05-04    Penang State, Malaysia        297587
#
#    Citizenship  Family Income (estimated) Application Type Application Date  \
# 0      Foreign                       6254              BKK       2020-10-26
# 1      Foreign                       9526              BKK       2022-03-08
# 2      Foreign                       8956              BKK       2020-07-21
# 3      Foreign                       7159              BKK       2021-02-11
# 4      Foreign                       7817              BKK       2020-05-30
# ..         ...                        ...              ...              ...
# 94   Malaysian                       6457              BKK       2021-04-18
# 95     Foreign                       9366              BKK       2021-04-27
# 96      Others                       6058              BKK       2022-11-02
# 97      Others                       8695              BKK       2020-03-20
# 98     Foreign                       8778              BKK       2023-05-31
#
#     Amount  Unnamed: 9  Unnamed: 10 Unnamed: 11
# 0      150         NaN          NaN         NaN
# 1      200         NaN          NaN        Liam
# 2      200         NaN          NaN      Olivia
# 3      150         NaN          NaN        Noah
# 4      150         NaN          NaN        Emma
# ..     ...         ...          ...         ...
# 94     150         NaN          NaN         NaN
# 95     200         NaN          NaN         NaN
# 96     150         NaN          NaN         NaN
# 97     150         NaN          NaN         NaN
# 98     150         NaN          NaN         NaN
#
# [99 rows x 12 columns]

# %% [markdown]
# ### Excel Output

# %%
ex.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ### HTML Input/Output
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
import pandas as pd

dfs = pd.read_html('data.html')

# dfs is a list of DataFrames (since there can be multiple tables in an HTML file)
# Select the first DataFrame from the list (if there's only one table)
df = dfs[0]

# Now df contains the data from the HTML table as a pandas DataFrame
print(df)

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Name': ['Arun', 'Prajakta', 'Kavita'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 70000]
}

df = pd.DataFrame(data)

# Save the DataFrame as an HTML table in 'output.html' file
df.to_html('output.html', index=False)

print("DataFrame saved as 'output.html' file.")
# Out:
# DataFrame saved as 'output.html' file.

# %% [markdown]
# ### JSON Input/Output

# %%
import pandas as pd

# Read JSON file into a pandas DataFrame
df = pd.read_json('data.json')

# Now df contains the data from the JSON file as a pandas DataFrame
print(df)
# Out:
#        name  age  salary
# 0     Rekha   25   50000
# 1     Ruchi   30   60000
# 2  Yuvarani   35   70000

# %%
import pandas as pd

# Sample DataFrame
data = {
    'name': ['Rekha', 'Ruchi', 'Yuvarani'],
    'age': [25, 30, 35],
    'salary': [50000, 60000, 70000]
}

df = pd.DataFrame(data)

# Save the DataFrame as a JSON file
df.to_json('output.json', orient='records')

print("DataFrame saved as 'output.json' file.")
# Out:
# DataFrame saved as 'output.json' file.

# %% [markdown]
# # SQL (Optional)
#
# * Note: If you are completely unfamiliar with SQL you can check out my other course: "Complete SQL Bootcamp" to learn SQL.

# %% [markdown]
# The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
#
# If SQLAlchemy is not installed, a fallback is only provided for sqlite (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('data', engine)

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df
# Out:
#    index      name  age  salary
# 0      0     Rekha   25   50000
# 1      1     Ruchi   30   60000
# 2      2  Yuvarani   35   70000

# %% [markdown]
# # Great Job!
